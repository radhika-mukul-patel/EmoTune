# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import lyricsgenius
import random
import json
import re

# %%
genius = lyricsgenius.Genius("YOUR API KEY GOES HERE", timeout=30)

# %%
# Define the genre-artist mappings
genre_artists = {
    "Metal": ["Metallica", "Black Sabbath", "Iron Maiden", "Slayer", "Pantera"],
    "Pop": ["Taylor Swift", "Katy Perry", "Justin Bieber", "Ariana Grande", "Maroon 5"],
   "Hip-Hop/Rap": ["Jay-Z", "Kendrick Lamar", "Drake", "Eminem", "Kanye West"],
  "Country": ["Johnny Cash", "Dolly Parton", "Luke Bryan", "Carrie Underwood", "Willie Nelson"],
   "R&B/Soul": ["Aretha Franklin", "Marvin Gaye", "Beyoncé", "Sam Cooke", "Stevie Wonder"],
   "EDM": ["Daft Punk", "Calvin Harris", "Avicii", "The Chainsmokers", "Marshmello"],
   "Jazz": ["Miles Davis", "Louis Armstrong", "Ella Fitzgerald", "Billie Holiday", "John Coltrane"],
   "Blues": ["B.B. King", "Robert Johnson", "Muddy Waters", "Eric Clapton", "Stevie Ray Vaughan"],
   "Reggae": ["Bob Marley", "Peter Tosh", "Toots and the Maytals", "Damian Marley", "Sean Paul"],
   "Metal": ["Metallica", "Black Sabbath", "Iron Maiden", "Slayer", "Pantera"]
}

# %%
# Initialize the list to store song data
song_data = []

# %%
# Iterate over the genre-artist mappings
for genre, artists in genre_artists.items():
    # Iterate over each artist
    for artist in artists:
        # Search for the artist's songs using the Genius API
        artist_search = genius.search_artist(artist, max_songs=20)
        
        # Retrieve 20 random songs from the artist's songs
        random_songs = random.sample(artist_search.songs, 20)
        
        # Extract song name and lyrics from each song and clean them up
        for song in random_songs:
            song_name = song.title
            lyrics = song.lyrics
            
            # Remove first row
            lyrics = re.sub(r'^.*?\n', '', lyrics)
            
            # Remove contributor information and translations
            lyrics = re.sub(r'\[.*?\]', '', lyrics)
            
            # Remove newline escape sequences (\n) and preserve spaces
            lyrics = lyrics.replace('\n', ' ')
            
            # Remove multiple spaces between words
            lyrics = re.sub(r'\s+', ' ', lyrics)
            
            # Remove "Embed" and the number before it
            lyrics = re.sub(r'\d+\s*Embed', '', lyrics)
            
            # Remove leading and trailing whitespace
            lyrics = lyrics.strip()
            
            # Append the song data to the list
            song_data.append({'Genre': genre, 'Artist': artist, 'Song Name': song_name, 'Lyrics': lyrics})
# Out:
# Searching for songs by Metallica...
#
# Song 1: "Nothing Else Matters"
# Song 2: "One"
# Song 3: "Enter Sandman"
# Song 4: "Master of Puppets"
# Song 5: "The Unforgiven"
# Song 6: "Fade to Black"
# Song 7: "For Whom the Bell Tolls"
# Song 8: "Sad But True"
# Song 9: "Creeping Death"
# Song 10: "Welcome Home (Sanitarium)"
# Song 11: "...And Justice for All"
# Song 12: "Wherever I May Roam"
# Song 13: "Battery"
# Song 14: "Ride the Lightning"
# Song 15: "Blackened"
# Song 16: "The Unforgiven II"
# Song 17: "The Four Horsemen"
# Song 18: "Whiplash"
# Song 19: "Dyers Eve"
# Song 20: "Seek & Destroy"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by Black Sabbath...
#
# Song 1: "Paranoid"
# Song 2: "Iron Man"
# Song 3: "War Pigs"
# Song 4: "N.I.B."
# Song 5: "Black Sabbath"
# Song 6: "Heaven and Hell"
# Song 7: "Changes"
# Song 8: "Planet Caravan"
# Song 9: "Sabbath Bloody Sabbath"
# Song 10: "Sweet Leaf"
# Song 11: "Children of the Grave"
# Song 12: "Fairies Wear Boots"
# Song 13: "Electric Funeral"
# Song 14: "Hand of Doom"
# Song 15: "Snowblind"
# Song 16: "God Is Dead?"
# Song 17: "Solitude"
# Song 18: "Into the Void"
# Song 19: "The Wizard"
# Song 20: "Warning"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by Iron Maiden...
#
# Song 1: "The Number of the Beast"
# Song 2: "Fear of the Dark"
# Song 3: "The Trooper"
# Song 4: "Hallowed Be Thy Name"
# Song 5: "Run to the Hills"
# Song 6: "2 Minutes to Midnight"
# Song 7: "Rime of the Ancient Mariner"
# Song 8: "Aces High"
# Song 9: "Wasted Years"
# Song 10: "The Writing on the Wall"
# Song 11: "Dance of Death"
# Song 12: "Phantom of the Opera"
# Song 13: "Revelations"
# Song 14: "Powerslave"
# Song 15: "Empire of the Clouds"
# Song 16: "Wasting Love"
# Song 17: "The Evil That Men Do"
# Song 18: "Iron Maiden"
# Song 19: "Brave New World"
# Song 20: "Hell on Earth"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by Slayer...
#
# Song 1: "Angel of Death"
# Song 2: "Raining Blood"
# Song 3: "Dead Skin Mask"
# Song 4: "South of Heaven"
# Song 5: "Seasons in the Abyss"
# Song 6: "Evil Has No Boundaries"
# Song 7: "Postmortem"
# Song 8: "Disciple"
# Song 9: "Repentless"
# Song 10: "Hell Awaits"
# Song 11: "War Ensemble"
# Song 12: "Jesus Saves"
# Song 13: "Bloodline"
# Song 14: "World Painted Blood"
# Song 15: "Piece by Piece"
# Song 16: "Mandatory Suicide"
# Song 17: "Altar of Sacrifice"
# Song 18: "Jihad"
# Song 19: "Black Magic"
# Song 20: "Silent Scream"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.
# Searching for songs by Pantera...
#
# Song 1: "Walk"
# Song 2: "Cemetery Gates"
# Song 3: "This Love"
# Song 4: "Cowboys from Hell"
# Song 5: "Domination"
# Song 6: "5 Minutes Alone"
# Song 7: "I’m Broken"
# Song 8: "Floods"
# Song 9: "Hollow"
# Song 10: "Mouth for War"
# Song 11: "Suicide Note Pt. I"
# Song 12: "Fucking Hostile"
# Song 13: "Suicide Note Pt. II"
# Song 14: "10's"
# Song 15: "A New Level"
# Song 16: "Good Friends and a Bottle of Pills"
# Song 17: "The Great Southern Trendkill"
# Song 18: "Becoming"
# Song 19: "No Good (Attack the Radical)"
# Song 20: "Rise"
#
# Reached user-specified song limit (20).
# Done. Found 20 songs.

# %%
# Create a pandas DataFrame
metal_df = pd.DataFrame(song_data)

# %%
# Display the DataFrame
display(metal_df)
# Out:
#     Genre     Artist                  Song Name  \
# 0   Metal  Metallica               Sad But True
# 1   Metal  Metallica                   Whiplash
# 2   Metal  Metallica  Welcome Home (Sanitarium)
# 3   Metal  Metallica             The Unforgiven
# 4   Metal  Metallica              Enter Sandman
# ..    ...        ...                        ...
# 95  Metal    Pantera                 Domination
# 96  Metal    Pantera                     Floods
# 97  Metal    Pantera                 I’m Broken
# 98  Metal    Pantera                     Hollow
# 99  Metal    Pantera             Cemetery Gates
#
#                                                Lyrics
# 0   Hey (Hey), I'm your life, I'm the one who take...
# 1   Late at night, all systems go You've come to s...
# 2   Welcome to where time stands still No one leav...
# 3   New blood joins this Earth, and quickly he's s...
# 4   Say your prayers, little one, don't forget, my...
# ..                                                ...
# 95  (First take like a motherfucker) Agony is the ...
# 96  A dead issue (A dead issue) Don't wrestle with...
# 97  I wonder if we'll smile in our coffins While l...
# 98  What's left inside him? Don't he remember us? ...
# 99  Reverend, reverend Is this some conspiracy? Cr...
#
# [100 rows x 4 columns]

# %%
metal_df.to_csv('metal_lyrics.csv', index=False)

# %%
# List of file names
file_names = ['blues_lyrics.csv', 'country_lyrics.csv', 'edm_lyrics.csv', 'hiphop_rap_lyrics.csv', 'jazz_lyrics.csv', 'metal_lyrics.csv', 'pop_lyrics.csv', 'reggae_lyrics.csv', 'RNB_Soul_lyrics.csv', 'rock_lyrics.csv']

# Create an empty list to store the dataframes
dfs = []

# Read each CSV file and append its dataframe to the list
for file in file_names:
    df = pd.read_csv(file)
    dfs.append(df)

# Concatenate the dataframes into one
merged_df = pd.concat(dfs, ignore_index=True)

# Display the merged dataframe
display(merged_df)

# Save the merged dataframe to a CSV file
merged_df.to_csv('lyrics.csv', index=False)
# Out:
#      Genre         Artist                     Song Name  \
# 0    Blues      B.B. King   I’m Working On the Building
# 1    Blues      B.B. King            Sweet Little Angel
# 2    Blues      B.B. King     Everyday I Have the Blues
# 3    Blues      B.B. King             You Upset Me Baby
# 4    Blues      B.B. King           Three O’Clock Blues
# ..     ...            ...                           ...
# 995   Rock  Guns N' Roses              Used to Love Her
# 996   Rock  Guns N' Roses                   This I Love
# 997   Rock  Guns N' Roses  Don’t Cry (Alternate Lyrics)
# 998   Rock  Guns N' Roses                      Patience
# 999   Rock  Guns N' Roses         Welcome to the Jungle
#
#                                                 Lyrics
# 0    It's a true foundation I'm lifting up a bloods...
# 1    I love the way she spread her wings Yes got a ...
# 2    Everyday, everyday I have the blues Ooooh, eve...
# 3    28 in the waist, 44 in the hips She got a real...
# 4    And I can't even close my eyes Three o'clock i...
# ..                                                 ...
# 995  I used to love her, but I had to kill her I us...
# 996  And now, I don't know why she wouldn't say goo...
# 997  If we could see tomorrow, what of your plans? ...
# 998  One, two, one, two, three, four *Whistling* Sh...
# 999  Oh my God Jump Welcome to the jungle, we got f...
#
# [1000 rows x 4 columns]
